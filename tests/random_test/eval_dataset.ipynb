# %%
import sys
sys.path.append("../../")
from test.evaluation.dataset_generator import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 3
#       1 import sys
#       2 sys.path.append("../../")
# ----> 3 from test.evaluation.dataset_generator import *
#
# ModuleNotFoundError: No module named 'test.evaluation'
