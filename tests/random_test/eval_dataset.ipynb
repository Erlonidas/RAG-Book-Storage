# %%
import sys
sys.path.append("../../")
import tests.evaluation.dataset_generator as eval_dataset
# Out:
# 2026-03-23 14:23:33 - src.services.opensearch - INFO - Connection with OpenSearch has been achieved. Version: 3.5.0

# %%
file_json = "s00521-025-11716-2.json"

# %%
eval_dataset.main(file_json=file_json, batch_size=5)
# Out:
# 2026-03-23 14:23:39 - src.services.llm_factory - INFO - Criando cliente OpenAI com modelo: gpt-4o-mini
# 2026-03-23 14:23:42 - tests.evaluation.dataset_generator - INFO - File Json detected: s00521-025-11716-2.json
# 2026-03-23 14:23:43 - src.services.opensearch - INFO - 110 chunks retrieved from index 'content-pdfs' filtered by pdf_name='s00521-025-11716-2.pdf'
# 2026-03-23 14:23:43 - tests.evaluation.dataset_generator - INFO - Recuperados 110 chunks. Total de páginas: 18
# 2026-03-23 14:23:43 - tests.evaluation.dataset_generator - INFO - Generating question-answer data...
# 2026-03-23 14:23:52 - tests.evaluation.dataset_generator - INFO - 5 records appended to 'c:\Users\Erlonidas\Documents\deploys\rag_book_challenge\tests\random_test\..\..\data\dataset_evaluation\ground_truth_dataset.csv'
# ...
